# %%
# Hello, Python!
# Python was named for the British comey troupe Monty Python, so we'll make our first Pyton program a homage to their skit about Spam

spam_amount = 0
print(spam_amount)

# Ordering Spam, egg, Spamm, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

if spam_amount > 0 :
    print("But I d'ont want ANY spam!")

viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# 0
# But I d'ont want ANY spam!
# Spam Spam Spam Spam

# %%
type(spam_amount)
# Out:
# int

# %%
# Order of operations is PEMDAS
# Parentheses - Exponents - Multiplication/Division - Addition/Subtraction

-3 + 4 * 2
# Out:
# 5

# %%
# Sometimes the default order of operations isn't what we want, then you can add the parentheses to force Python
# to evaluate sub-expressions in whatever order you want.
hat_height_cm = 25
my_height_cm = 190

# how tall am I, in meters, when wearing my hat?
total_heigth_meters = (hat_height_cm + my_height_cm) / 100
print("Height in meters: ", total_heigth_meters)
# Out:
# Height in meters:  2.15

# %% [markdown]
# Here is the table of available arithmetic operations:
#
#
# | Operator     | Name           | Description                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | Addition       | Sum of ``a`` and ``b``                                 |
# | ``a - b``    | Subtraction    | Difference of ``a`` and ``b``                          |
# | ``a * b``    | Multiplication | Product of ``a`` and ``b``                             |
# | ``a / b``    | True division  | Quotient of ``a`` and ``b``                            |
# | ``a // b``   | Floor division | Quotient of ``a`` and ``b``, removing fractional parts |
# | ``a % b``    | Modulus        | Integer remainder after division of ``a`` by ``b``     |
# | ``a ** b``   | Exponentiation | ``a`` raised to the power of ``b``                     |
# | ``-a``       | Negation       | The negative of ``a``                                  |
